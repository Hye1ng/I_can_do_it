# %% [markdown]
# # 과제

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
game_df =  pd.read_csv("./game.csv")

game_df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
game_df.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
game_df['Genre'].unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
game_df[['Genre', 'Global_Sales']].groupby(['Genre'])

# %%
g_s = game_df[['Genre', 'Global_Sales']].groupby(['Genre']).count()
g_s
# Out:
#               Global_Sales
# Genre
# Action                3316
# Adventure             1286
# Fighting               848
# Misc                  1739
# Platform               886
# Puzzle                 582
# Racing                1249
# Role-Playing          1488
# Shooter               1310
# Simulation             867
# Sports                2346
# Strategy               681

# %%
plt.plot(g_s)

plt.show()

# %% [markdown]
# ## Action이 세계에서 제일 잘 팔리는 장르

# %% [markdown]
# - 추가 (하지만 Sports 장르에서 가장 잘 팔리는 게임이 존재함)

# %%
g= sns.catplot(x= "Genre", y= 'Global_Sales', data= game_df)
g.fig.set_size_inches(10, 6)
plt.show()

# %% [markdown]
# #### 위에서 확인한 것처럼 가장 잘 팔리는 게임이 어떤 게임인지 확인해보겠습니다!
# (사실 데이터 가장 위에 있어 확인하기 쉽지만 데이터를 시각화하는 연습을 해보겠습니다)

# %%
sports = game_df[game_df["Genre"] == 'Sports'] 
sports
# Out:
#         Rank                           Name Platform    Year   Genre  \
# 0          1                     Wii Sports      Wii  2006.0  Sports
# 3          4              Wii Sports Resort      Wii  2009.0  Sports
# 13        14                        Wii Fit      Wii  2007.0  Sports
# 14        15                   Wii Fit Plus      Wii  2009.0  Sports
# 77        78                        FIFA 16      PS4  2015.0  Sports
# ...      ...                            ...      ...     ...     ...
# 16576  16579              Rugby Challenge 3     XOne  2016.0  Sports
# 16578  16581  Outdoors Unleashed: Africa 3D      3DS  2011.0  Sports
# 16579  16582              PGA European Tour      N64  2000.0  Sports
# 16581  16584                      Fit & Fun      Wii  2011.0  Sports
# 16587  16590       Mezase!! Tsuri Master DS       DS  2009.0  Sports
#
#                   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
sports.loc[sports['Global_Sales'].idxmax(), 'Name']
# Out:
# 'Wii Sports'

# %%
sports['Global_Sales'].max()
# Out:
# 82.74

# %% [markdown]
# ## Sports 장르에서 가장 인기 많은 건 Wii Sports
#
# 그래프로 나타내려고 했는데 (*) 에서 움직이질 않네요.... 너무 많아서 그런가봐요 ㅠㅠㅠ
#
#
# `sns.stripplot(x= 'Name', y= 'Global_Sales', data=sports)`
#
# `plt.show()`

# %%
game_df['Platform'].unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        '3DS', 'PS4', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne', 'GC',
#        'WiiU', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %%
sns.countplot(x='Platform', data = game_df)
plt.figure(figsize=(20, 15))
plt.show()

# %% [markdown]
# ## 가장 인기 있는 Game Platform은 DB

# %%
game_df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
game_df[game_df["Platform"] == 'DB']

# 이건 대체 왜 안 뜨는 걸까요? ㅠㅠ
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Platform, Year, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales]
# Index: []

# %%
game_df['Publisher']
# Out:
# 0          Nintendo
# 1          Nintendo
# 2          Nintendo
# 3          Nintendo
# 4          Nintendo
#             ...
# 16593         Kemco
# 16594    Infogrames
# 16595    Activision
# 16596      7G//AMES
# 16597       Wanadoo
# Name: Publisher, Length: 16598, dtype: object

# %%
game_df['Publisher'].unique()
# Out:
# array(['Nintendo', 'Microsoft Game Studios', 'Take-Two Interactive',
#        'Sony Computer Entertainment', 'Activision', 'Ubisoft',
#        'Bethesda Softworks', 'Electronic Arts', 'Sega', 'SquareSoft',
#        'Atari', '505 Games', 'Capcom', 'GT Interactive',
#        'Konami Digital Entertainment',
#        'Sony Computer Entertainment Europe', 'Square Enix', 'LucasArts',
#        'Virgin Interactive', 'Warner Bros. Interactive Entertainment',
#        'Universal Interactive', 'Eidos Interactive', 'RedOctane',
#        'Vivendi Games', 'Enix Corporation', 'Namco Bandai Games',
#        'Palcom', 'Hasbro Interactive', 'THQ', 'Fox Interactive',
#        'Acclaim Entertainment', 'MTV Games', 'Disney Interactive Studios',
#        nan, 'Majesco Entertainment', 'Codemasters', 'Red Orb', 'Level 5',
#        'Arena Entertainment', 'Midway Games', 'JVC', 'Deep Silver',
#        '989 Studios', 'NCSoft', 'UEP Systems', 'Parker Bros.', 'Maxis',
# ...

# %%
game_df[['Publisher', 'Global_Sales']].groupby(['Publisher'])

# %%
pu_sales_count = game_df[['Publisher', 'Global_Sales']].groupby(['Publisher']).count()
pu_sales_count
# Out:
#                               Global_Sales
# Publisher
# 10TACLE Studios                          3
# 1C Company                               3
# 20th Century Fox Video Games             5
# 2D Boy                                   1
# 3DO                                     36
# ...                                    ...
# id Software                              1
# imageepoch Inc.                          2
# inXile Entertainment                     1
# mixi, Inc                                1
# responDESIGN                             2
#
# [578 rows x 1 columns]

# %%
pu_sales_count.idxmax()
# Out:
# Global_Sales    Electronic Arts
# dtype: object

# %%
pu_sales_count.max()
# Out:
# Global_Sales    1351
# dtype: int64

# %%
plt.plot(pu_sales_count)

plt.show()

# %% [markdown]
# ### 가장 게임이 많은 회사는 Electronic Arts, 총 1351개

# %%
many = game_df[['Publisher', 'Global_Sales']].groupby(['Publisher']).idxmax()
many
# Out:
#                               Global_Sales
# Publisher
# 10TACLE Studios                      12349
# 1C Company                           13057
# 20th Century Fox Video Games          2596
# 2D Boy                               14011
# 3DO                                   1544
# ...                                    ...
# id Software                          14599
# imageepoch Inc.                      14259
# inXile Entertainment                 10756
# mixi, Inc                             2409
# responDESIGN                         10945
#
# [578 rows x 1 columns]

# %%
many.idxmax()
# Out:
# Global_Sales    UIG Entertainment
# dtype: object

# %%
many.max()
# Out:
# Global_Sales    16570
# dtype: int64

# %% [markdown]
# ### 가장 많이 팔고 있는 회사는 UIG Entertainment, 총 16570개 판매

# %%
game_df[['Rank', 'Name']].groupby('Name')

# %%
Top10 = game_df[['Rank', 'Name']].groupby('Name').head(10)

# groupby는 .head() 함수가 안 되는 건가요?? 검색해보니까 그룹을 직접 지정해서 해야 하던데   
#저는 예시처럼 그룹이 여러개가 아니라서 어떻게 해야 할지 모르겠어요

# %%
rank = game_df.sort_values(by='Rank').head(10)
rank
# Out:
#    Rank                       Name Platform    Year         Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9    10                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# ...
